# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def trans(arr):
    x_ = arr[0] - 40.7062855
    y_ = arr[1] + 74.0315102
    return [x_,y_]

# %%
top = [40.7738362, -73.9985950]
left = [40.7062855, -74.0315102]
right = [40.7613036, -73.9541783]
bottom = [40.6937655, -73.9871323]

# %%
a_ = np.array(trans(bottom))
b_ = np.array(trans(top))
print(a_, b_)

a = a_ / np.linalg.norm(a_)
b = b_ / np.linalg.norm(b_)
print(a,b)

r = trans(right)
    # print(r)

maxa = np.dot(r,b)
maxb = np.dot(r,a)
# Out:
# [-0.01252    0.0443779] [0.0675507 0.0329152]
# [-0.27152357  0.96243179] [0.89895903 0.43803271]

# %%
for number in range(1,13):
    df2 = pd.read_csv('D:\\bicycle_data\\2019{}-citibike-tripdata.csv'.format(str(number).zfill(2)),usecols=[1,2,4,5,6,9,10])
    raw_data2 = pd.DataFrame(df2)
    raw_data2.dropna(inplace=True)
    raw_data2=raw_data2[(raw_data2['start station name']!='Division Ave & Hooper St') &( raw_data2['start station name']!='Cliff St & Fulton St (Old)')&( raw_data2['start station name']!='Division St & Bowery (old)')]
    raw_data2=raw_data2[(raw_data2['start station name']!='Lafayette St & Jersey St S') &( raw_data2['start station name']!='W Broadway & Spring St')&( raw_data2['start station name']!='Broadway & W 36 St')]
    raw_data2=raw_data2[(raw_data2['start station name']!='Pershing Square South') &( raw_data2['start station name']!='W 45 St & 6 Ave -')&( raw_data2['start station name']!='E 58 St & 1 Ave')]
    raw_data2['start station longitude_tran'] = raw_data2['start station longitude'] + 74.0315102
    raw_data2['start station latitude_tran'] = raw_data2['start station latitude'] - 40.7062855
    raw_data2['end station longitude_tran'] = raw_data2['end station longitude'] + 74.0315102
    raw_data2['end station latitude_tran'] = raw_data2['end station latitude'] - 40.7062855
    raw_data2['start_x_temp'] = raw_data2['start station latitude_tran'] * b[0] + raw_data2['start station longitude_tran'] * b[1]
    raw_data2['start_y_temp'] = raw_data2['start station latitude_tran'] * a[0] + raw_data2['start station longitude_tran'] * a[1]
    raw_data2['end_x_temp'] = raw_data2['end station latitude_tran'] * b[0] + raw_data2['end station longitude_tran'] * b[1]
    raw_data2['end_y_temp'] = raw_data2['end station latitude_tran'] * a[0] + raw_data2['end station longitude_tran'] * a[1]
    raw_data2['start_x'] = raw_data2['start_x_temp']*8 // maxa
    raw_data2['start_y'] = raw_data2['start_y_temp']*16 // maxb
    raw_data2['end_x'] = raw_data2['end_x_temp']*8 // maxa
    raw_data2['end_y'] = raw_data2['end_y_temp']*16 // maxb
    raw_data2.drop(inplace=True,axis=1,columns=['start_x_temp','start_y_temp','end_x_temp','end_y_temp','start station longitude_tran','start station latitude_tran','end station longitude_tran','end station latitude_tran'])
    raw_data=raw_data2[(raw_data2['start_x']>=0)&(raw_data2['end_x']>=0)&(raw_data2['start_y']>=0)&(raw_data2['end_y']>=0)&(raw_data2['start_x']<8)&(raw_data2['end_x']<8)&(raw_data2['start_y']<16)&(raw_data2['end_y']<16)]
    raw_data.reset_index(inplace=True,drop=True)
    raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
    raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
    raw_data['start_day'] = raw_data['starttime'].dt.date
    raw_data['start_hour'] = raw_data['starttime'].dt.hour
    raw_data['stop_day'] = raw_data['stoptime'].dt.date
    raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
    last_re=raw_data[['start_day','start_hour','start_x','start_y']]
    last_re=pd.DataFrame(last_re)
    result_start_notime =pd.DataFrame(last_re.groupby(['start_x','start_y'],as_index=False).size())
    result_start_notime.to_csv('D:\\bicycle_result\\2019{}-citibike_grid.csv'.format(str(number).zfill(2)),index=None)
    print(number)
# Out:
# <ipython-input-6-1ddf3255875a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-6-1ddf3255875a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-6-1ddf3255875a>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-6-1ddf3255875a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 1
# <ipython-input-6-1ddf3255875a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-6-1ddf3255875a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-6-1ddf3255875a>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-6-1ddf3255875a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 2
# <ipython-input-6-1ddf3255875a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-6-1ddf3255875a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-6-1ddf3255875a>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-6-1ddf3255875a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 3
# <ipython-input-6-1ddf3255875a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-6-1ddf3255875a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-6-1ddf3255875a>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-6-1ddf3255875a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 4
# <ipython-input-6-1ddf3255875a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-6-1ddf3255875a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-6-1ddf3255875a>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-6-1ddf3255875a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 5
# <ipython-input-6-1ddf3255875a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-6-1ddf3255875a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-6-1ddf3255875a>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-6-1ddf3255875a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 6
# <ipython-input-6-1ddf3255875a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-6-1ddf3255875a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-6-1ddf3255875a>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-6-1ddf3255875a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 7
# <ipython-input-6-1ddf3255875a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-6-1ddf3255875a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-6-1ddf3255875a>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-6-1ddf3255875a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 8
# <ipython-input-6-1ddf3255875a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-6-1ddf3255875a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-6-1ddf3255875a>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-6-1ddf3255875a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 9
# <ipython-input-6-1ddf3255875a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-6-1ddf3255875a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-6-1ddf3255875a>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-6-1ddf3255875a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 10
# <ipython-input-6-1ddf3255875a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-6-1ddf3255875a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-6-1ddf3255875a>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-6-1ddf3255875a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 11
# <ipython-input-6-1ddf3255875a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-6-1ddf3255875a>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-6-1ddf3255875a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-6-1ddf3255875a>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-6-1ddf3255875a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 12

# %%
for number in range(1,13):
    df2 = pd.read_csv('D:\\bicycle_data\\2020{}-citibike-tripdata.csv'.format(str(number).zfill(2)),usecols=[1,2,4,5,6,9,10])
    raw_data2 = pd.DataFrame(df2)
    raw_data2.dropna(inplace=True)
    raw_data2=raw_data2[(raw_data2['start station name']!='Franklin St & W Broadway') &( raw_data2['start station name']!='Lispenard St & Broadway')&( raw_data2['start station name']!='W Broadway & Spring St [temporarily removed]')]
    raw_data2=raw_data2[(raw_data2['start station name']!='LaGuardia Pl & W 3 St [temporarily removed]') &( raw_data2['start station name']!='1 Ave & E 16 St [temporarily removed]')&( raw_data2['start station name']!='1 Ave & E 18 St [temporarily removed]')]
    raw_data2=raw_data2[(raw_data2['start station name']!='University Pl & E 14 St') &( raw_data2['start station name']!='E 25 St & 1 Ave')&( raw_data2['start station name']!='Lexington Ave & E 26 St [temporarily removed]')]
    raw_data2=raw_data2[(raw_data2['start station name']!='Greenpoint Ave & Manhattan Ave [temporarily removed]') &( raw_data2['start station name']!='Lexington Ave & E 29 St [temporarily removed]')&( raw_data2['start station name']!='W 26 St & 8 Ave')]
    raw_data2=raw_data2[(raw_data2['start station name']!='W 31 St & 7 Ave [temporarily removed]') &( raw_data2['start station name']!='24 St & 41 Ave (original)')&( raw_data2['start station name']!='31 Ave & Steinway St (temp)')]
    raw_data2=raw_data2[(raw_data2['start station name']!='5 Ave & E 72 St') &( raw_data2['start station name']!='Central Park West & W 85 St (old)')&( raw_data2['start station name']!='Madison Ave & E 99 St')]
    raw_data2=raw_data2[(raw_data2['start station name']!='Frederick Douglass Blvd & W 115 St') &( raw_data2['start station name']!='OLD Southern Blvd & E 142 St')&( raw_data2['start station name']!='E 170 St & Webster Ave_old')]
    raw_data2['start station longitude_tran'] = raw_data2['start station longitude'] + 74.0315102
    raw_data2['start station latitude_tran'] = raw_data2['start station latitude'] - 40.7062855
    raw_data2['end station longitude_tran'] = raw_data2['end station longitude'] + 74.0315102
    raw_data2['end station latitude_tran'] = raw_data2['end station latitude'] - 40.7062855
    raw_data2['start_x_temp'] = raw_data2['start station latitude_tran'] * b[0] + raw_data2['start station longitude_tran'] * b[1]
    raw_data2['start_y_temp'] = raw_data2['start station latitude_tran'] * a[0] + raw_data2['start station longitude_tran'] * a[1]
    raw_data2['end_x_temp'] = raw_data2['end station latitude_tran'] * b[0] + raw_data2['end station longitude_tran'] * b[1]
    raw_data2['end_y_temp'] = raw_data2['end station latitude_tran'] * a[0] + raw_data2['end station longitude_tran'] * a[1]
    raw_data2['start_x'] = raw_data2['start_x_temp']*8 // maxa
    raw_data2['start_y'] = raw_data2['start_y_temp']*16 // maxb
    raw_data2['end_x'] = raw_data2['end_x_temp']*8 // maxa
    raw_data2['end_y'] = raw_data2['end_y_temp']*16 // maxb
    raw_data2.drop(inplace=True,axis=1,columns=['start_x_temp','start_y_temp','end_x_temp','end_y_temp','start station longitude_tran','start station latitude_tran','end station longitude_tran','end station latitude_tran'])
    raw_data=raw_data2[(raw_data2['start_x']>=0)&(raw_data2['end_x']>=0)&(raw_data2['start_y']>=0)&(raw_data2['end_y']>=0)&(raw_data2['start_x']<8)&(raw_data2['end_x']<8)&(raw_data2['start_y']<16)&(raw_data2['end_y']<16)]
    raw_data.reset_index(inplace=True,drop=True)
    raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
    raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
    raw_data['start_day'] = raw_data['starttime'].dt.date
    raw_data['start_hour'] = raw_data['starttime'].dt.hour
    raw_data['stop_day'] = raw_data['stoptime'].dt.date
    raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
    last_re=raw_data[['start_day','start_hour','start_x','start_y']]
    last_re=pd.DataFrame(last_re)
    result_start_notime =pd.DataFrame(last_re.groupby(['start_x','start_y'],as_index=False).size())
    result_start_notime.to_csv('D:\\bicycle_result\\2020{}-citibike_grid.csv'.format(str(number).zfill(2)),index=None)
    print(number)
# Out:
# <ipython-input-8-91d39dbef408>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-8-91d39dbef408>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-8-91d39dbef408>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-8-91d39dbef408>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 1
# <ipython-input-8-91d39dbef408>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-8-91d39dbef408>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-8-91d39dbef408>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-8-91d39dbef408>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 2
# <ipython-input-8-91d39dbef408>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-8-91d39dbef408>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-8-91d39dbef408>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-8-91d39dbef408>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 3
# <ipython-input-8-91d39dbef408>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-8-91d39dbef408>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-8-91d39dbef408>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-8-91d39dbef408>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 4
# <ipython-input-8-91d39dbef408>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-8-91d39dbef408>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-8-91d39dbef408>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-8-91d39dbef408>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 5
# <ipython-input-8-91d39dbef408>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-8-91d39dbef408>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-8-91d39dbef408>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-8-91d39dbef408>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 6
# <ipython-input-8-91d39dbef408>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-8-91d39dbef408>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-8-91d39dbef408>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-8-91d39dbef408>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 7
# <ipython-input-8-91d39dbef408>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-8-91d39dbef408>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-8-91d39dbef408>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-8-91d39dbef408>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 8
# <ipython-input-8-91d39dbef408>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-8-91d39dbef408>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-8-91d39dbef408>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-8-91d39dbef408>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 9
# <ipython-input-8-91d39dbef408>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-8-91d39dbef408>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-8-91d39dbef408>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-8-91d39dbef408>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 10
# <ipython-input-8-91d39dbef408>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-8-91d39dbef408>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-8-91d39dbef408>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-8-91d39dbef408>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 11
# <ipython-input-8-91d39dbef408>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-8-91d39dbef408>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-8-91d39dbef408>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# 12
# <ipython-input-8-91d39dbef408>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-8-91d39dbef408>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour

# %%
df3_1= pd.read_csv('D:\\bicycle_data\\2021{}-citibike-tripdata.csv'.format(str(1).zfill(2)))
raw_data2=pd.DataFrame(df3_1)
raw_data2['start station longitude_tran'] = raw_data2['start station longitude'] + 74.0315102
raw_data2['start station latitude_tran'] = raw_data2['start station latitude'] - 40.7062855
raw_data2['end station longitude_tran'] = raw_data2['end station longitude'] + 74.0315102
raw_data2['end station latitude_tran'] = raw_data2['end station latitude'] - 40.7062855
raw_data2['start_x_temp'] = raw_data2['start station latitude_tran'] * b[0] + raw_data2['start station longitude_tran'] * b[1]
raw_data2['start_y_temp'] = raw_data2['start station latitude_tran'] * a[0] + raw_data2['start station longitude_tran'] * a[1]
raw_data2['end_x_temp'] = raw_data2['end station latitude_tran'] * b[0] + raw_data2['end station longitude_tran'] * b[1]
raw_data2['end_y_temp'] = raw_data2['end station latitude_tran'] * a[0] + raw_data2['end station longitude_tran'] * a[1]
raw_data2['start_x'] = raw_data2['start_x_temp']*8 // maxa
raw_data2['start_y'] = raw_data2['start_y_temp']*16 // maxb
raw_data2['end_x'] = raw_data2['end_x_temp']*8 // maxa
raw_data2['end_y'] = raw_data2['end_y_temp']*16 // maxb
raw_data2.drop(inplace=True,axis=1,columns=['start_x_temp','start_y_temp','end_x_temp','end_y_temp','start station longitude_tran','start station latitude_tran','end station longitude_tran','end station latitude_tran'])
raw_data=raw_data2[(raw_data2['start_x']>=0)&(raw_data2['end_x']>=0)&(raw_data2['start_y']>=0)&(raw_data2['end_y']>=0)&(raw_data2['start_x']<8)&(raw_data2['end_x']<8)&(raw_data2['start_y']<16)&(raw_data2['end_y']<16)]
raw_data.reset_index(inplace=True,drop=True)
raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
raw_data['start_day'] = raw_data['starttime'].dt.date
raw_data['start_hour'] = raw_data['starttime'].dt.hour
raw_data['stop_day'] = raw_data['stoptime'].dt.date
raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
last_re=raw_data[['start_day','start_hour','start_x','start_y']]
last_re=pd.DataFrame(last_re)
result_start_notime =pd.DataFrame(last_re.groupby(['start_x','start_y'],as_index=False).size())
result_start_notime.to_csv('D:\\bicycle_result\\2021{}-citibike_grid.csv'.format(str(1).zfill(2)),index=None)
print(number)
# Out:
# <ipython-input-9-957cc3de856f>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
# <ipython-input-9-957cc3de856f>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
# <ipython-input-9-957cc3de856f>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-9-957cc3de856f>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-9-957cc3de856f>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-9-957cc3de856f>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 12

# %%
for number in range(2, 9):
    df3 = pd.read_csv('D:\\bicycle_data\\2021{}-citibike-tripdata.csv'.format(str(number).zfill(2)))
    raw_data2=pd.DataFrame(df3)
    raw_data2.dropna(inplace=True)
    raw_data2.rename(columns={'start_lat':'start station latitude', 'start_lng':'start station longitude', 'end_lat':'end station latitude','end_lng':'end station longitude'}, inplace = True)
    raw_data2.drop_duplicates(keep='first',inplace=True)
            
    raw_data2["starttime"]= pd.to_datetime(raw_data2['started_at'],errors='coerce')
    raw_data2["stoptime"]= pd.to_datetime(raw_data2['ended_at'],errors='coerce')



    raw_data2['start station longitude_tran'] = raw_data2['start station longitude'] + 74.0315102
    raw_data2['start station latitude_tran'] = raw_data2['start station latitude'] - 40.7062855
    raw_data2['end station longitude_tran'] = raw_data2['end station longitude'] + 74.0315102
    raw_data2['end station latitude_tran'] = raw_data2['end station latitude'] - 40.7062855
    raw_data2['start_x_temp'] = raw_data2['start station latitude_tran'] * b[0] + raw_data2['start station longitude_tran'] * b[1]
    raw_data2['start_y_temp'] = raw_data2['start station latitude_tran'] * a[0] + raw_data2['start station longitude_tran'] * a[1]
    raw_data2['end_x_temp'] = raw_data2['end station latitude_tran'] * b[0] + raw_data2['end station longitude_tran'] * b[1]
    raw_data2['end_y_temp'] = raw_data2['end station latitude_tran'] * a[0] + raw_data2['end station longitude_tran'] * a[1]
    raw_data2['start_x'] = raw_data2['start_x_temp']*8 // maxa
    raw_data2['start_y'] = raw_data2['start_y_temp']*16 // maxb
    raw_data2['end_x'] = raw_data2['end_x_temp']*8 // maxa
    raw_data2['end_y'] = raw_data2['end_y_temp']*16 // maxb
    raw_data2.drop(inplace=True,axis=1,columns=['start_x_temp','start_y_temp','end_x_temp','end_y_temp','start station longitude_tran','start station latitude_tran','end station longitude_tran','end station latitude_tran'])
    raw_data=raw_data2[(raw_data2['start_x']>=0)&(raw_data2['end_x']>=0)&(raw_data2['start_y']>=0)&(raw_data2['end_y']>=0)&(raw_data2['start_x']<8)&(raw_data2['end_x']<8)&(raw_data2['start_y']<16)&(raw_data2['end_y']<16)]
    raw_data.reset_index(inplace=True,drop=True)
    # raw_data['starttime'] = pd.to_datetime(raw_data['starttime'],errors='coerce')
    # raw_data['stoptime'] = pd.to_datetime(raw_data['stoptime'],errors='coerce')
    raw_data['start_day'] = raw_data['starttime'].dt.date
    raw_data['start_hour'] = raw_data['starttime'].dt.hour
    raw_data['stop_day'] = raw_data['stoptime'].dt.date
    raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
    last_re=raw_data[['start_day','start_hour','start_x','start_y']]
    last_re=pd.DataFrame(last_re)
    result_start_notime =pd.DataFrame(last_re.groupby(['start_x','start_y'],as_index=False).size())
    result_start_notime.to_csv('D:\\bicycle_result\\2021{}-citibike_grid.csv'.format(str(number).zfill(2)),index=None)
    print(number)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-10-56becac341e3>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-10-56becac341e3>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-10-56becac341e3>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-10-56becac341e3>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 2
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-10-56becac341e3>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-10-56becac341e3>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-10-56becac341e3>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-10-56becac341e3>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 3
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-10-56becac341e3>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-10-56becac341e3>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-10-56becac341e3>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-10-56becac341e3>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 4
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-10-56becac341e3>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-10-56becac341e3>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-10-56becac341e3>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-10-56becac341e3>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 5
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-10-56becac341e3>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-10-56becac341e3>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-10-56becac341e3>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-10-56becac341e3>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 6
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-10-56becac341e3>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-10-56becac341e3>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-10-56becac341e3>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-10-56becac341e3>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 7
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-10-56becac341e3>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_day'] = raw_data['starttime'].dt.date
# <ipython-input-10-56becac341e3>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['start_hour'] = raw_data['starttime'].dt.hour
# <ipython-input-10-56becac341e3>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_day'] = raw_data['stoptime'].dt.date
# <ipython-input-10-56becac341e3>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['stop_hour'] = raw_data['stoptime'].dt.hour
# 8
